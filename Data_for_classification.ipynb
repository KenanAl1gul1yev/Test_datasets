# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Data_for_classification.csv')
df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
cols_to_drop = ['fnlwgt', 'race']
df.drop(cols_to_drop, axis = 'columns', inplace = True)
df
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0       39         State-gov  Bachelors             13       Never-married
# 1       50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2       38           Private    HS-grad              9            Divorced
# 3       53           Private       11th              7  Married-civ-spouse
# 4       28           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48837   39           Private  Bachelors             13            Divorced
# 48838   64               NaN    HS-grad              9             Widowed
# 48839   38           Private  Bachelors             13  Married-civ-spouse
# 48840   44           Private  Bachelors             13            Divorced
# 48841   35      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
# ...

# %%
cols = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'sex', 'native-country']
for i in cols:
    print(df.groupby(i)[i].agg('count').sort_values(ascending = False))
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# ?                    1836
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# ...

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K', '<=50K.', '>50K.'], dtype=object)

# %%
df.replace({'?': np.NaN, '>50K.': '>50K', '<=50K.': '<=50K'}, inplace = True)
df
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0       39         State-gov  Bachelors             13       Never-married
# 1       50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2       38           Private    HS-grad              9            Divorced
# 3       53           Private       11th              7  Married-civ-spouse
# 4       28           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48837   39           Private  Bachelors             13            Divorced
# 48838   64               NaN    HS-grad              9             Widowed
# 48839   38           Private  Bachelors             13  Married-civ-spouse
# 48840   44           Private  Bachelors             13            Divorced
# 48841   35      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
# ...

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df.dropna(inplace = True)
df
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0       39         State-gov  Bachelors             13       Never-married
# 1       50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2       38           Private    HS-grad              9            Divorced
# 3       53           Private       11th              7  Married-civ-spouse
# 4       28           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48836   33           Private  Bachelors             13       Never-married
# 48837   39           Private  Bachelors             13            Divorced
# 48839   38           Private  Bachelors             13  Married-civ-spouse
# 48840   44           Private  Bachelors             13            Divorced
# 48841   35      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
# ...

# %%
numeric_cols = ['age', 'education-num', 'capital-gain', 'capital-loss','hours-per-week']
categorical_cols = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'sex', 'native-country', 'income']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df
# Out:
#             age         workclass  education  education-num  \
# 0      0.301370         State-gov  Bachelors       0.800000
# 1      0.452055  Self-emp-not-inc  Bachelors       0.800000
# 2      0.287671           Private    HS-grad       0.533333
# 3      0.493151           Private       11th       0.400000
# 4      0.150685           Private  Bachelors       0.800000
# ...         ...               ...        ...            ...
# 48836  0.219178           Private  Bachelors       0.800000
# 48837  0.301370           Private  Bachelors       0.800000
# 48839  0.287671           Private  Bachelors       0.800000
# 48840  0.369863           Private  Bachelors       0.800000
# 48841  0.246575      Self-emp-inc  Bachelors       0.800000
#
#            marital-status         occupation   relationship     sex  \
# 0           Never-married       Adm-clerical  Not-in-family    Male
# 1      Married-civ-spouse    Exec-managerial        Husband    Male
# ...

# %%
df1 = pd.get_dummies(data = df, columns = categorical_cols, drop_first = True)
df1
# Out:
#             age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0      0.301370       0.800000      0.021740           0.0        0.397959
# 1      0.452055       0.800000      0.000000           0.0        0.122449
# 2      0.287671       0.533333      0.000000           0.0        0.397959
# 3      0.493151       0.400000      0.000000           0.0        0.397959
# 4      0.150685       0.800000      0.000000           0.0        0.397959
# ...         ...            ...           ...           ...             ...
# 48836  0.219178       0.800000      0.000000           0.0        0.397959
# 48837  0.301370       0.800000      0.000000           0.0        0.357143
# 48839  0.287671       0.800000      0.000000           0.0        0.500000
# 48840  0.369863       0.800000      0.054551           0.0        0.397959
# 48841  0.246575       0.800000      0.000000           0.0        0.602041
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df1.drop(['income_>50K'], axis = 'columns'), df1['income_>50K'], test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#             age  education-num  capital-gain  capital-loss  hours-per-week  \
# 8624   0.205479       0.800000           0.0           0.0        0.397959
# 28487  0.383562       0.733333           0.0           0.0        0.663265
# 33913  0.383562       0.400000           0.0           0.0        0.500000
# 14435  0.301370       0.533333           0.0           0.0        0.704082
# 41844  0.465753       0.533333           0.0           0.0        0.377551
# ...         ...            ...           ...           ...             ...
# 12203  0.123288       0.600000           0.0           0.0        0.397959
# 48312  0.095890       0.800000           0.0           0.0        0.500000
# 41204  0.191781       0.600000           0.0           0.0        0.397959
# 935    0.273973       0.533333           0.0           0.0        1.000000
# 17056  0.534247       0.400000           0.0           0.0        0.397959
#
# ...

# %%
y_train
# Out:
# 8624     False
# 28487    False
# 33913    False
# 14435    False
# 41844    False
#          ...
# 12203    False
# 48312    False
# 41204    False
# 935       True
# 17056    False
# Name: income_>50K, Length: 36177, dtype: bool

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)
clf.fit(x_train, y_train)
clf.score(x_test, y_test)
# Out:
# 0.8435599778883361
